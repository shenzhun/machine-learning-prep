# %% [markdown]
# <a href="https://colab.research.google.com/github/shenzhun/machine-learning-brushup/blob/master/visualizations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import datasets
digits = datasets.load_digits()
X = digits.data[:500]
y = digits.target[:500]

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=0)

# %%
X_embedded = tsne.fit_transform(X)
print(X_embedded[:, [1]])
# Out:
# [[-27.16831   ]
#  [ 19.58326   ]
#  [ 15.290366  ]
#  [-21.091736  ]
#  [ 23.603703  ]
#  [-17.34772   ]
#  [  4.7650127 ]
#  [ 17.295044  ]
#  [  2.502906  ]
#  [-10.366336  ]
#  [-24.605005  ]
#  [ 23.313835  ]
#  [  0.46654528]
#  [-21.453371  ]
#  [ 21.205591  ]
#  [ -2.7342186 ]
#  [  2.4900124 ]
#  [ 20.866518  ]
#  [  7.604591  ]
#  [-19.935587  ]
#  [-25.343437  ]
#  [ 25.307953  ]
#  [  1.6689622 ]
#  [-22.117968  ]
#  [ 23.414707  ]
#  [ -4.139865  ]
#  [  5.4630337 ]
#  [ 17.928284  ]
#  [  4.4480467 ]
#  [-19.425783  ]
#  [-29.89854   ]
#  [-19.656553  ]
#  [ -7.3002253 ]
#  [ -3.8945363 ]
#  [  1.7005308 ]
#  [ -4.0247464 ]
#  [-26.933842  ]
#  [-20.913483  ]
#  [  7.9841313 ]
#  [-14.17573   ]
#  [  4.3080482 ]
#  [ 20.89112   ]
#  [ 23.013193  ]
#  [ 18.431936  ]
#  [ 18.205235  ]
#  [-23.245022  ]
#  [ -2.7986157 ]
#  [ 23.29171   ]
#  [-28.474627  ]
#  [-24.763168  ]
#  [ 14.666392  ]
#  [ 16.198263  ]
#  [ 17.636703  ]
#  [  5.4372425 ]
#  [ 16.61369   ]
# ...

# %%
target_ids = range(len(digits.target_names))

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(7, 7))
colors = 'r', 'g', 'b', 'c', 'm', 'y', 'k', 'w', 'orange', 'purple'

for i, c, label in zip(target_ids, colors, digits.target_names):
    plt.scatter(X_embedded[y == i, 0], X_embedded[y == i, 1], c=c, label=label)
  
plt.legend()
plt.show()
