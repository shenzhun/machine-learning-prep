# %% [markdown]
# <a href="https://colab.research.google.com/github/shenzhun/machine-learning-brushup/blob/master/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# # Lines

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)

# %%
plt.plot(x, y)
plt.show()

# %% [markdown]
# # Scalar Plot

# %%
plt.xlabel("Time")
plt.ylabel("Sone function of time")
plt.title("my first cool chart")
plt.plot(x, y)
plt.show()

# %%
x_line = np.linspace(0, 100, 100)
y_line = 2 * x_line + 1
plt.scatter(x, y)

plt.plot(x_line, y_line)

# %%
R = np.random.random(10000)
# plt.hist(R)


plt.hist(R, bins=20)
# Out:
# (array([502., 551., 486., 514., 498., 475., 510., 553., 485., 519., 499.,
#         472., 498., 478., 481., 482., 547., 478., 492., 480.]),
#  array([2.68798866e-05, 5.00246753e-02, 1.00022471e-01, 1.50020266e-01,
#         2.00018062e-01, 2.50015857e-01, 3.00013652e-01, 3.50011448e-01,
#         4.00009243e-01, 4.50007039e-01, 5.00004834e-01, 5.50002629e-01,
#         6.00000425e-01, 6.49998220e-01, 6.99996016e-01, 7.49993811e-01,
#         7.99991606e-01, 8.49989402e-01, 8.99987197e-01, 9.49984993e-01,
#         9.99982788e-01]),
#  <a list of 20 Patch objects>)

# %%
df = pd.read_csv("./sample_data/mnist/train.csv")
df.shape
# Out:
# (42000, 785)

# %%
M = df.to_numpy()
im = M[0, 1:]
im.shape
# Out:
# (784,)

# %%
im = im.reshape(28, 28)
im.shape
plt.imshow(im)

# %%
plt.imshow(im, cmap='gray')
